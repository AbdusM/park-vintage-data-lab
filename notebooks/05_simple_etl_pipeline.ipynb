# %% [markdown]
# # Mission 5: Simple ETL Pipeline
# Clean inventory and create monthly summaries in two small steps.

# %%
import subprocess
from pathlib import Path

# %%
# Run the cleaner
root = Path('..')
subprocess.run(['python', str(root / 'src' / 'clean_inventory.py')], check=True)

# %%
# Build the database
subprocess.run(['python', str(root / 'src' / 'build_store_database.py')], check=True)

# %%
# Create monthly summary
subprocess.run(['python', str(root / 'src' / 'sales_summary.py')], check=True)

# %%
from pathlib import Path
print('Cleaned inventory:', (Path('..') / 'data' / 'processed' / 'cleaned_inventory.csv').exists())
print('Monthly summary:', (Path('..') / 'data' / 'processed' / 'monthly_sales_summary.csv').exists())

# %% [markdown]
# Use the generated CSV files in `data/processed/` as the basis for your final report.
