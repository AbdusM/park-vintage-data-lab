# %% [markdown]
# # Mission 0: Project Tour
# Welcome to Park Vintage Data Lab.

# %% [markdown]
# ## Folder map
# You will work in these main folders:
# - data/raw: source data
# - data/processed: generated output files
# - notebooks: step-by-step learning notebooks
# - sql: starter SQL exercises
# - src: Python scripts
# - reports: example and learner outputs
# - exercises: copyable missions

# %%
from pathlib import Path
for folder in ["data", "data/raw", "notebooks", "sql", "src", "reports", "exercises"]:
    print(Path(folder).exists(), folder)

# %% [markdown]
# ## Quick check
# Use this command in your terminal before continuing:
# `git status`
# This project is safe to edit as long as you keep changes readable.

# %%
from pathlib import Path
print('Current notebook path:', Path().resolve())
print('Project root hint:', Path('..').resolve())
