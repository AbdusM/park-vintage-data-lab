# %% [markdown]
# # Mission 2: Python Inventory Basics
# Load the inventory data and run a few beginner checks.

# %%
import pandas as pd
from pathlib import Path

# %%
inventory_path = Path('..') / 'data' / 'raw' / 'inventory.csv'
inventory = pd.read_csv(inventory_path)
inventory.head()

# %%
inventory.shape

# %%
inventory['category'].value_counts()

# %%
top_price = inventory.sort_values('list_price', ascending=False)
top_price[['item_id', 'product_name', 'category', 'list_price']].head(10)

# %% [markdown]
# ## Your exercise
# 1. How many items are marked `Sold`?
# 2. What is the most expensive in-stock item?
# 3. Which category has the most rows?
