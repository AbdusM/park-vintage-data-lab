# %% [markdown]
# # Mission 5: Simple ETL Pipeline
# Clean inventory and create monthly summaries in two small steps.

# %%
import subprocess
from pathlib import Path

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent

# %%
# Run the cleaner
subprocess.run(['python', str(repo_root / 'src' / 'clean_inventory.py')], check=True)

# %%
# Build the database
subprocess.run(['python', str(repo_root / 'src' / 'build_store_database.py')], check=True)

# %%
# Create monthly summary
subprocess.run(['python', str(repo_root / 'src' / 'sales_summary.py')], check=True)

# %%
print('Cleaned inventory:', (repo_root / 'data' / 'processed' / 'cleaned_inventory.csv').exists())
print('Monthly summary:', (repo_root / 'data' / 'processed' / 'monthly_sales_summary.csv').exists())

# %% [markdown]
# Use the generated CSV files in `data/processed/` as the basis for your final report.
